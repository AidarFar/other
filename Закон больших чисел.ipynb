# %%
import random

def calculate_p(N):
  cnt_21_40 = 0
  for i in range(N):
    random_integer = random.randint(1,100)
    if random_integer >=21 and random_integer<=40:
      cnt_21_40 = cnt_21_40 + 1
  return cnt_21_40 / N
p_20 = calculate_p(10000)
print(p_20)
# Out:
# 0.2011
